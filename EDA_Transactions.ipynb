# %%
import pandas as pd

# %%
df = pd.read_csv("Transactions.csv")

# %%
# df.head()
df
# Out:
#            transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 0         1-11-2024-10138            11               1        مبايعات
# 1             3-9-2002-39             9               3           هبات
# 2         1-11-2016-12930            11               1        مبايعات
# 3        1-11-2005-300028            11               1        مبايعات
# 4         1-11-2010-17709            11               1        مبايعات
# ...                   ...           ...             ...            ...
# 1428575   1-41-2023-12911            41               1        مبايعات
# 1428576   1-11-2010-11938            11               1        مبايعات
# 1428577   1-11-2012-25350            11               1        مبايعات
# 1428578   1-11-2012-25431            11               1        مبايعات
# 1428579     1-11-2016-951            11               1        مبايعات
#
#         trans_group_en procedure_name_ar procedure_name_en instance_date  \
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'procedure_id', 'trans_group_id', 'trans_group_ar',
#        'trans_group_en', 'procedure_name_ar', 'procedure_name_en',
#        'instance_date', 'property_type_id', 'property_type_ar',
#        'property_type_en', 'property_sub_type_id', 'property_sub_type_ar',
#        'property_sub_type_en', 'property_usage_ar', 'property_usage_en',
#        'reg_type_id', 'reg_type_ar', 'reg_type_en', 'area_id', 'area_name_ar',
#        'area_name_en', 'building_name_ar', 'building_name_en',
#        'project_number', 'project_name_ar', 'project_name_en',
#        'master_project_en', 'master_project_ar', 'nearest_landmark_ar',
#        'nearest_landmark_en', 'nearest_metro_ar', 'nearest_metro_en',
#        'nearest_mall_ar', 'nearest_mall_en', 'rooms_ar', 'rooms_en',
#        'has_parking', 'procedure_area', 'actual_worth', 'meter_sale_price',
#        'rent_value', 'meter_rent_price', 'no_of_parties_role_1',
#        'no_of_parties_role_2', 'no_of_parties_role_3'],
# ...

# %%
df = df[[
    'transaction_id', 'procedure_id', 'trans_group_id', 'trans_group_en',
    'procedure_name_en', 'instance_date', 'property_type_id', 'property_type_en',
    'property_sub_type_id', 'property_sub_type_en', 'property_usage_en',
    'reg_type_id', 'reg_type_en', 'area_id', 'area_name_en', 'building_name_en',
    'project_number', 'project_name_en', 'master_project_en',
    'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en', 'rooms_en',
    'has_parking', 'procedure_area', 'actual_worth', 'meter_sale_price',
    'rent_value', 'meter_rent_price', 'no_of_parties_role_1',
    'no_of_parties_role_2', 'no_of_parties_role_3'
]]

# %%
df
# Out:
#            transaction_id  procedure_id  trans_group_id trans_group_en  \
# 0         1-11-2024-10138            11               1          Sales
# 1             3-9-2002-39             9               3          Gifts
# 2         1-11-2016-12930            11               1          Sales
# 3        1-11-2005-300028            11               1          Sales
# 4         1-11-2010-17709            11               1          Sales
# ...                   ...           ...             ...            ...
# 1428575   1-41-2023-12911            41               1          Sales
# 1428576   1-11-2010-11938            11               1          Sales
# 1428577   1-11-2012-25350            11               1          Sales
# 1428578   1-11-2012-25431            11               1          Sales
# 1428579     1-11-2016-951            11               1          Sales
#
#         procedure_name_en instance_date  property_type_id property_type_en  \
# ...

# %%
df['reg_type_en'].value_counts()
# Out:
# reg_type_en
# Existing Properties    965758
# Off-Plan Properties    462822
# Name: count, dtype: int64

# %%
# My goal is predict the actual_worth so I m ignoring some unnecessary columns 

df = df[[
    'transaction_id', 'trans_group_en',
    'procedure_name_en', 'instance_date', 'property_type_en',
    'property_sub_type_en', 'property_usage_en',
    'reg_type_en', 'area_name_en', 'building_name_en',
    'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en', 'rooms_en',
    'has_parking', 'procedure_area', 'actual_worth'
]]

# %%
df
# Out:
#            transaction_id trans_group_en procedure_name_en instance_date  \
# 0         1-11-2024-10138          Sales              Sell    19-03-2024
# 1             3-9-2002-39          Gifts             Grant    25-03-2002
# 2         1-11-2016-12930          Sales              Sell    02-11-2016
# 3        1-11-2005-300028          Sales              Sell    28-02-2005
# 4         1-11-2010-17709          Sales              Sell    09-12-2010
# ...                   ...            ...               ...           ...
# 1428575   1-41-2023-12911          Sales      Delayed Sell    11-07-2023
# 1428576   1-11-2010-11938          Sales              Sell    03-08-2010
# 1428577   1-11-2012-25350          Sales              Sell    24-12-2012
# 1428578   1-11-2012-25431          Sales              Sell    25-12-2012
# 1428579     1-11-2016-951          Sales              Sell    26-01-2016
#
#         property_type_en property_sub_type_en         property_usage_en  \
# ...

# %%
df.dtypes
# Out:
# transaction_id           object
# trans_group_en           object
# procedure_name_en        object
# instance_date            object
# property_type_en         object
# property_sub_type_en     object
# property_usage_en        object
# reg_type_en              object
# area_name_en             object
# building_name_en         object
# nearest_landmark_en      object
# nearest_metro_en         object
# nearest_mall_en          object
# rooms_en                 object
# has_parking               int64
# procedure_area          float64
# actual_worth            float64
# dtype: object

# %%
import matplotlib.pyplot as plt

df.plot()
plt.show()

# %%
df['actual_worth'].hist(bins=60)
# Out:
# <Axes: >

# %%
df[df['actual_worth']>10000000000]
# Out:
#           transaction_id trans_group_en                procedure_name_en  \
# 84845       2-49-2023-95      Mortgages  Portfolio Mortgage Modification
# 234355       2-49-2024-6      Mortgages  Portfolio Mortgage Modification
# 368042      2-43-2023-12      Mortgages  Portfolio Mortgage Registration
# 437069     2-43-2022-147      Mortgages  Portfolio Mortgage Registration
# 526523     2-43-2022-148      Mortgages  Portfolio Mortgage Registration
# 559722     2-43-2022-117      Mortgages  Portfolio Mortgage Registration
# 782546      2-49-2023-92      Mortgages  Portfolio Mortgage Modification
# 880763     2-39-2016-417      Mortgages             Development Mortgage
# 923122     2-43-2022-151      Mortgages  Portfolio Mortgage Registration
# 1028588     2-49-2023-13      Mortgages  Portfolio Mortgage Modification
# 1045267    2-43-2022-149      Mortgages  Portfolio Mortgage Registration
# 1063837     2-49-2022-50      Mortgages  Portfolio Mortgage Modification
# ...

# %%
df[['transaction_id', 'actual_worth']].plot(kind='scatter', x='transaction_id', y='actual_worth')
